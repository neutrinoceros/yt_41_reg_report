# %%
import yt
ds = yt.load_sample("IsolatedGalaxy")
# Out:
# yt : [INFO     ] 2022-10-10 15:20:16,662 Sample dataset found in '/Users/robcleme/dev/yt-project/test-data-dir/IsolatedGalaxy/galaxy0030/galaxy0030'
# yt : [INFO     ] 2022-10-10 15:20:16,784 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2022-10-10 15:20:16,786 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2022-10-10 15:20:16,787 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-10 15:20:16,789 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-10 15:20:16,790 Parameters: cosmological_simulation   = 0

# %%
p = yt.SlicePlot(ds, "z", ("gas", "density"), width=0.5)
p
# Out:
# Parsing Hierarchy : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 173/173 [00:00<00:00, 7111.22it/s]
# yt : [INFO     ] 2022-10-10 15:20:17,445 Gathering a field list (this may take a moment.)

# %%
p.annotate_velocity() # in yt 4.0.5, this cell triggers a new render, correctly annotated. In yt 4.1.0, there are no graphic returns
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p # in yt 4.1, this triggers a new render, but the annotation isn't added
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## attempt 2

# %%
p = yt.SlicePlot(ds, "z", ("gas", "density"), width=0.5)
p.annotate_velocity()
p
# Out:
# yt : [INFO     ] 2022-10-10 15:07:26,132 xlim = 0.250000 0.750000
# yt : [INFO     ] 2022-10-10 15:07:26,133 ylim = 0.250000 0.750000
# yt : [INFO     ] 2022-10-10 15:07:26,134 xlim = 0.250000 0.750000
# yt : [INFO     ] 2022-10-10 15:07:26,135 ylim = 0.250000 0.750000
# yt : [INFO     ] 2022-10-10 15:07:26,137 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
